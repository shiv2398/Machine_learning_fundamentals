# %%
import pandas as pd

# %%
a=pd.Series([1,2,3,4,5])#going to be homogenous

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a[3]#retrieve value
# Out:
# 4

# %%
a[2]
# Out:
# 3

# %%
a=pd.Series(['a','b','c'])

# %%
a
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
#when series in string we denoting it as object

# %%
a=pd.date_range(start='01-02-2018',end='16-03-2020')

# %%
a
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-06', '2018-01-07', '2018-01-08', '2018-01-09',
#                '2018-01-10', '2018-01-11',
#                ...
#                '2020-03-07', '2020-03-08', '2020-03-09', '2020-03-10',
#                '2020-03-11', '2020-03-12', '2020-03-13', '2020-03-14',
#                '2020-03-15', '2020-03-16'],
#               dtype='datetime64[ns]', length=805, freq='D')

# %%
type(a)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
#panda Data Frame
import numpy as np

# %%
temp=np.random.randint(low=20,high=100,size=[20,])
name =np.random.choice(['Abhay','teclove','geeksub','shiv'],20)
random=np.random.choice([10,11,13,12,12],20)

# %%
a=list(zip(temp,name,random))

# %%
df=pd.DataFrame(data=a,columns=['temp','name','random'])

# %%
df
# Out:
#     temp     name  random
# 0     66     shiv      12
# 1     48    Abhay      12
# 2     96     shiv      10
# 3     87  teclove      12
# 4     72    Abhay      10
# 5     39     shiv      10
# 6     27  teclove      12
# 7     42     shiv      13
# 8     30    Abhay      12
# 9     94  teclove      11
# 10    47  teclove      12
# 11    70  teclove      10
# 12    95  teclove      10
# 13    48    Abhay      12
# 14    36  geeksub      10
# 15    79    Abhay      12
# 16    88     shiv      12
# 17    87     shiv      10
# 18    54  teclove      12
# 19    76  teclove      11

# %%
df=pd.DataFrame({'temp':temp,'name':name,'random':random})

# %%
df
# Out:
#     temp     name  random
# 0     66     shiv      12
# 1     48    Abhay      12
# 2     96     shiv      10
# 3     87  teclove      12
# 4     72    Abhay      10
# 5     39     shiv      10
# 6     27  teclove      12
# 7     42     shiv      13
# 8     30    Abhay      12
# 9     94  teclove      11
# 10    47  teclove      12
# 11    70  teclove      10
# 12    95  teclove      10
# 13    48    Abhay      12
# 14    36  geeksub      10
# 15    79    Abhay      12
# 16    88     shiv      12
# 17    87     shiv      10
# 18    54  teclove      12
# 19    76  teclove      11

# %%
df.head()
# Out:
#    temp     name  random
# 0    66     shiv      12
# 1    48    Abhay      12
# 2    96     shiv      10
# 3    87  teclove      12
# 4    72    Abhay      10

# %%
df.tail()
# Out:
#     temp     name  random
# 15    79    Abhay      12
# 16    88     shiv      12
# 17    87     shiv      10
# 18    54  teclove      12
# 19    76  teclove      11

# %%
df.shape
# Out:
# (20, 3)

# %%
df.columns
# Out:
# Index(['temp', 'name', 'random'], dtype='object')

# %%
df.name
# Out:
# 0        shiv
# 1       Abhay
# 2        shiv
# 3     teclove
# 4       Abhay
# 5        shiv
# 6     teclove
# 7        shiv
# 8       Abhay
# 9     teclove
# 10    teclove
# 11    teclove
# 12    teclove
# 13      Abhay
# 14    geeksub
# 15      Abhay
# 16       shiv
# 17       shiv
# 18    teclove
# 19    teclove
# Name: name, dtype: object

# %%
df['name']
# Out:
# 0        shiv
# 1       Abhay
# 2        shiv
# 3     teclove
# 4       Abhay
# 5        shiv
# 6     teclove
# 7        shiv
# 8       Abhay
# 9     teclove
# 10    teclove
# 11    teclove
# 12    teclove
# 13      Abhay
# 14    geeksub
# 15      Abhay
# 16       shiv
# 17       shiv
# 18    teclove
# 19    teclove
# Name: name, dtype: object

# %%
df['temp'].describe()
# Out:
# count    20.000000
# mean     64.050000
# std      23.295527
# min      27.000000
# 25%      45.750000
# 50%      68.000000
# 75%      87.000000
# max      96.000000
# Name: temp, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   temp    20 non-null     int64
#  1   name    20 non-null     object
#  2   random  20 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 608.0+ bytes

# %%
df.values
# Out:
# array([[66, 'shiv', 12],
#        [48, 'Abhay', 12],
#        [96, 'shiv', 10],
#        [87, 'teclove', 12],
#        [72, 'Abhay', 10],
#        [39, 'shiv', 10],
#        [27, 'teclove', 12],
#        [42, 'shiv', 13],
#        [30, 'Abhay', 12],
#        [94, 'teclove', 11],
#        [47, 'teclove', 12],
#        [70, 'teclove', 10],
#        [95, 'teclove', 10],
#        [48, 'Abhay', 12],
#        [36, 'geeksub', 10],
#        [79, 'Abhay', 12],
#        [88, 'shiv', 12],
#        [87, 'shiv', 10],
#        [54, 'teclove', 12],
#        [76, 'teclove', 11]], dtype=object)

# %%
#indexing

# %%
df.set_index('temp')
# Out:
#          name  random
# temp
# 66       shiv      12
# 48      Abhay      12
# 96       shiv      10
# 87    teclove      12
# 72      Abhay      10
# 39       shiv      10
# 27    teclove      12
# 42       shiv      13
# 30      Abhay      12
# 94    teclove      11
# 47    teclove      12
# 70    teclove      10
# 95    teclove      10
# 48      Abhay      12
# 36    geeksub      10
# 79      Abhay      12
# 88       shiv      12
# 87       shiv      10
# 54    teclove      12
# 76    teclove      11

# %%
df
# Out:
#     temp     name  random
# 0     66     shiv      12
# 1     48    Abhay      12
# 2     96     shiv      10
# 3     87  teclove      12
# 4     72    Abhay      10
# 5     39     shiv      10
# 6     27  teclove      12
# 7     42     shiv      13
# 8     30    Abhay      12
# 9     94  teclove      11
# 10    47  teclove      12
# 11    70  teclove      10
# 12    95  teclove      10
# 13    48    Abhay      12
# 14    36  geeksub      10
# 15    79    Abhay      12
# 16    88     shiv      12
# 17    87     shiv      10
# 18    54  teclove      12
# 19    76  teclove      11

# %%
#how to fix it
#inplace by default is false if we do it true to make change True

# %%
df.sort_index(axis=0,ascending=True)
# Out:
#     temp     name  random
# 0     66     shiv      12
# 1     48    Abhay      12
# 2     96     shiv      10
# 3     87  teclove      12
# 4     72    Abhay      10
# 5     39     shiv      10
# 6     27  teclove      12
# 7     42     shiv      13
# 8     30    Abhay      12
# 9     94  teclove      11
# 10    47  teclove      12
# 11    70  teclove      10
# 12    95  teclove      10
# 13    48    Abhay      12
# 14    36  geeksub      10
# 15    79    Abhay      12
# 16    88     shiv      12
# 17    87     shiv      10
# 18    54  teclove      12
# 19    76  teclove      11

# %%
df.sort_values(by='random',inplace=True)

# %%
df
# Out:
#     temp     name  random
# 17    87     shiv      10
# 2     96     shiv      10
# 14    36  geeksub      10
# 4     72    Abhay      10
# 5     39     shiv      10
# 12    95  teclove      10
# 11    70  teclove      10
# 9     94  teclove      11
# 19    76  teclove      11
# 18    54  teclove      12
# 10    47  teclove      12
# 6     27  teclove      12
# 13    48    Abhay      12
# 3     87  teclove      12
# 15    79    Abhay      12
# 16    88     shiv      12
# 1     48    Abhay      12
# 8     30    Abhay      12
# 0     66     shiv      12
# 7     42     shiv      13

# %%
df.drop(['random'],axis=1)
# Out:
#     temp     name
# 17    87     shiv
# 2     96     shiv
# 14    36  geeksub
# 4     72    Abhay
# 5     39     shiv
# 12    95  teclove
# 11    70  teclove
# 9     94  teclove
# 19    76  teclove
# 18    54  teclove
# 10    47  teclove
# 6     27  teclove
# 13    48    Abhay
# 3     87  teclove
# 15    79    Abhay
# 16    88     shiv
# 1     48    Abhay
# 8     30    Abhay
# 0     66     shiv
# 7     42     shiv

# %%
df.head()
# Out:
#     temp     name  random
# 17    87     shiv      10
# 2     96     shiv      10
# 14    36  geeksub      10
# 4     72    Abhay      10
# 5     39     shiv      10

# %%
#iloc

# %%
df.iloc[[0,1]]
# Out:
#     temp  name  random
# 17    87  shiv      10
# 2     96  shiv      10

# %%
df.iloc[1:3,1]#third parameter for column
# Out:
# 2        shiv
# 14    geeksub
# Name: name, dtype: object

# %%
df.head()
# Out:
#     temp     name  random
# 17    87     shiv      10
# 2     96     shiv      10
# 14    36  geeksub      10
# 4     72    Abhay      10
# 5     39     shiv      10

# %%
df.iloc[0,:]
# Out:
# temp        87
# name      shiv
# random      10
# Name: 17, dtype: object

# %%
df.loc[3,:]
# Out:
# temp           87
# name      teclove
# random         12
# Name: 3, dtype: object

# %%
df.loc[[3,2,5]]
# Out:
#    temp     name  random
# 3    87  teclove      12
# 2    96     shiv      10
# 5    39     shiv      10

# %%
df.loc[[3,2],'name':'random']
# Out:
#       name  random
# 3  teclove      12
# 2     shiv      10

# %%
df.loc[[1,3,5,6]]
# Out:
#    temp     name  random
# 1    48    Abhay      12
# 3    87  teclove      12
# 5    39     shiv      10
# 6    27  teclove      12

# %%
df.loc[df.random>13]
# Out:
# Empty DataFrame
# Columns: [temp, name, random]
# Index: []

# %%
df.loc[(df.random>13)|(df.random==10),:]
# Out:
#     temp     name  random
# 17    87     shiv      10
# 2     96     shiv      10
# 14    36  geeksub      10
# 4     72    Abhay      10
# 5     39     shiv      10
# 12    95  teclove      10
# 11    70  teclove      10

# %%
#reading csv

# %%
df1=pd.read_csv("diabetes.csv")

# %%
df.to_excel('dia.xlsx',sheet_name="diabetes")

# %%
df2=pd.read_excel("dia.xlsx")

# %%
df2
# Out:
#     Unnamed: 0  temp     name  random
# 0           17    87     shiv      10
# 1            2    96     shiv      10
# 2           14    36  geeksub      10
# 3            4    72    Abhay      10
# 4            5    39     shiv      10
# 5           12    95  teclove      10
# 6           11    70  teclove      10
# 7            9    94  teclove      11
# 8           19    76  teclove      11
# 9           18    54  teclove      12
# 10          10    47  teclove      12
# 11           6    27  teclove      12
# 12          13    48    Abhay      12
# 13           3    87  teclove      12
# 14          15    79    Abhay      12
# 15          16    88     shiv      12
# 16           1    48    Abhay      12
# 17           8    30    Abhay      12
# 18           0    66     shiv      12
# 19           7    42     shiv      13

# %%
df2.to_csv('diabetes.csv')

# %%
df2.to_csv("diabetes.csv",index=False)

# %%
d1=pd.DataFrame([['a',1],['b',2]],columns=['col1','number'])
d2=pd.DataFrame([['c',3,'lion'],['d',4,'tiger']],columns=['letter','yes','f'])

# %%
df1.head()
# Out:
#    Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0           0            6      148             72             35        0
# 1           1            1       85             66             29        0
# 2           2            8      183             64              0        0
# 3           3            1       89             66             23       94
# 4           4            0      137             40             35      168
#
#     BMI  DiabetesPedigreeFunction  Age  Outcome
# 0  33.6                     0.627   50        1
# 1  26.6                     0.351   31        0
# 2  23.3                     0.672   32        1
# 3  28.1                     0.167   21        0
# 4  43.1                     2.288   33        1

# %%
d2
# Out:
#   letter  yes      f
# 0      c    3   lion
# 1      d    4  tiger

# %%
#row axis=0
pd.concat([d1,d2],axis=0)
# Out:
#   col1  number letter  yes      f
# 0    a     1.0    NaN  NaN    NaN
# 1    b     2.0    NaN  NaN    NaN
# 0  NaN     NaN      c  3.0   lion
# 1  NaN     NaN      d  4.0  tiger

# %%
#new indexs

# %%
pd.concat([d1,d2],axis=0,ignore_index=True)
# Out:
#   col1  number letter  yes      f
# 0    a     1.0    NaN  NaN    NaN
# 1    b     2.0    NaN  NaN    NaN
# 2  NaN     NaN      c  3.0   lion
# 3  NaN     NaN      d  4.0  tiger

# %%
pd.concat([d1,d2],axis=1)
# Out:
#   col1  number letter  yes      f
# 0    a       1      c    3   lion
# 1    b       2      d    4  tiger

# %%
#group by

# %%
df2
# Out:
#     Unnamed: 0  temp     name  random
# 0           17    87     shiv      10
# 1            2    96     shiv      10
# 2           14    36  geeksub      10
# 3            4    72    Abhay      10
# 4            5    39     shiv      10
# 5           12    95  teclove      10
# 6           11    70  teclove      10
# 7            9    94  teclove      11
# 8           19    76  teclove      11
# 9           18    54  teclove      12
# 10          10    47  teclove      12
# 11           6    27  teclove      12
# 12          13    48    Abhay      12
# 13           3    87  teclove      12
# 14          15    79    Abhay      12
# 15          16    88     shiv      12
# 16           1    48    Abhay      12
# 17           8    30    Abhay      12
# 18           0    66     shiv      12
# 19           7    42     shiv      13

# %%
df_group=df1.groupby(df1["Glucose"])

# %%
df_group

# %%
df_group.describe()
# Out:
#         Unnamed: 0                                                        \
#              count        mean         std    min     25%    50%     75%
# Glucose
# 0              5.0  290.000000  165.089370   75.0  182.00  342.0  349.00
# 44             1.0   62.000000         NaN   62.0   62.00   62.0   62.00
# 56             1.0  680.000000         NaN  680.0  680.00  680.0  680.00
# 57             2.0  341.500000  276.478751  146.0  243.75  341.5  439.25
# 61             1.0  352.000000         NaN  352.0  352.00  352.0  352.00
# ...            ...         ...         ...    ...     ...    ...     ...
# 195            2.0  586.500000  125.157900  498.0  542.25  586.5  630.75
# 196            3.0  195.666667  168.737469   22.0  114.00  206.0  282.50
# 197            4.0  305.750000  244.826980    8.0  173.00  318.0  450.75
# 198            1.0  561.000000         NaN  561.0  561.00  561.0  561.00
# 199            1.0  661.000000         NaN  661.0  661.00  661.0  661.00
#
# ...

# %%
def hot_temp(x):
    return x>30

# %%
df1['Glucose']=df1["Glucose"].apply(lambda x:x<30 )

# %%
df2
# Out:
#     Unnamed: 0  temp     name  random
# 0           17    87     shiv      10
# 1            2    96     shiv      10
# 2           14    36  geeksub      10
# 3            4    72    Abhay      10
# 4            5    39     shiv      10
# 5           12    95  teclove      10
# 6           11    70  teclove      10
# 7            9    94  teclove      11
# 8           19    76  teclove      11
# 9           18    54  teclove      12
# 10          10    47  teclove      12
# 11           6    27  teclove      12
# 12          13    48    Abhay      12
# 13           3    87  teclove      12
# 14          15    79    Abhay      12
# 15          16    88     shiv      12
# 16           1    48    Abhay      12
# 17           8    30    Abhay      12
# 18           0    66     shiv      12
# 19           7    42     shiv      13

# %%
d1=pd.DataFrame({'city':['s','y','agra','delhi'],
               'temp':[1,2,3,4]})

# %%
d2=pd.DataFrame({'city':['s','y','agra','delhi'],
               'humidity':[1,2,3,4]})

# %%
d1
# Out:
#     city  temp
# 0      s     1
# 1      y     2
# 2   agra     3
# 3  delhi     4

# %%
d2
# Out:
#     city  humidity
# 0      s         1
# 1      y         2
# 2   agra         3
# 3  delhi         4

# %%
pd.merge(d1,d2,on=['city'],how='left')
# Out:
#     city  temp  humidity
# 0      s     1         1
# 1      y     2         2
# 2   agra     3         3
# 3  delhi     4         4

# %%
pd.merge(d1,d2,on="city")
# Out:
#     city  temp  humidity
# 0      s     1         1
# 1      y     2         2
# 2   agra     3         3
# 3  delhi     4         4
